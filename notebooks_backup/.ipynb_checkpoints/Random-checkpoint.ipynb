# %%
# %matplotlib inline

from src import RandomPointsInBounds

# %%
aoi = '/data/swk.gpkg'
lyr_name = 'Sarawak'
n_points = 5000
min_distance = 100 # meters

# %%
params = {
    "input_polygon": aoi,
    "input_layer_name": lyr_name,
    "output_polygon": '/data/output.gpkg',
    "n_points": n_points,
    "minimum_distance": min_distance,
}
rand_pts = RandomPointsInBounds(**params)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
rand_pts.plot()

# %%
rand_pts.save()
# Out:
# Save as /data/output.gpkg || layername=random_5000
